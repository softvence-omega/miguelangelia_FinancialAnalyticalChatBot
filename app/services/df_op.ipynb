# %%
import pandas as pd

# %%
file= "apple_stock_data.csv"
df = pd.read_csv(file)
print("shape=", df.shape)
# Out:
# shape= (252, 6)

# %%
df.describe()
# Out:
#          Price               Close  High   Low  Open Volume
# count      252                 251   251   251   251    251
# unique     252                 248   251   251   251    251
# top     Ticker  174.13433837890625  AAPL  AAPL  AAPL   AAPL
# freq         1                   2     1     1     1      1

# %%
df
# Out:
#           Price               Close                High                 Low  \
# 0        Ticker                AAPL                AAPL                AAPL
# 1          Date                 NaN                 NaN                 NaN
# 2    2023-01-03  123.33064270019531  129.07955877586164  122.44315755676651
# 3    2023-01-04  124.60272979736328  126.87074702913759    123.340531781636
# 4    2023-01-05   123.2813491821289  125.99310505602139  123.02497040718632
# ..          ...                 ...                 ...                 ...
# 247  2023-12-22  191.97467041015625   193.7694724442452  191.34995462543642
# 248  2023-12-26  191.42929077148438    192.262235089905  191.21113652656177
# 249  2023-12-27  191.52842712402344   191.8754947947896  189.48572401895245
# 250  2023-12-28  191.95484924316406   193.0257841884141   191.5482876644632
# 251  2023-12-29  190.91366577148438  192.76796185552627  190.12037892679615
#
#                    Open     Volume
# ...
